# %%
#Ablation study framework

# %%
import pandas as pd
df = pd.read_csv("../data/week1_features.csv")
print("Shape:", df.shape)
# Out:
# Shape: (10000, 64)

# %%
model_a_features = [col for col in df.columns if 'roll' in col or col in 
    ["Air temperature [K]", "Process temperature [K]", "Rotational speed [rpm]", 
     "Torque [Nm]", "Tool wear [min]"]]
print("Model A features:", len(model_a_features))
# Out:
# Model A features: 55

# %%
model_b_features = model_a_features.copy()
print("Model B will extend Model A with contextual features")
# Out:
# Model B will extend Model A with contextual features
