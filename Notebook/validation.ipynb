# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv( r"C:\Users\ankit\Predictive-Maintenance-IoT-AI\Data\preprocessed_ai4i2020.csv" )
print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
print("Rows and Columns:")
print(df.shape)
# Out:
# Rows and Columns:
# (10000, 12)

# %%
print("Dataset Columns:") 
print(df.columns.tolist())
# Out:
# Dataset Columns:
# ['Type', 'Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]', 'Machine failure', 'TWF', 'HDF', 'PWF', 'OSF', 'RNF']

# %%
print("Data Types:")
print(df.dtypes)
# Out:
# Data Types:
# Type                         int64
# Air temperature [K]        float64
# Process temperature [K]    float64
# Rotational speed [rpm]     float64
# Torque [Nm]                float64
# Tool wear [min]            float64
# Machine failure              int64
# TWF                          int64
# HDF                          int64
# PWF                          int64
# OSF                          int64
# RNF                          int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Type                     10000 non-null  int64
#  1   Air temperature [K]      10000 non-null  float64
#  2   Process temperature [K]  10000 non-null  float64
#  3   Rotational speed [rpm]   10000 non-null  float64
#  4   Torque [Nm]              10000 non-null  float64
#  5   Tool wear [min]          10000 non-null  float64
#  6   Machine failure          10000 non-null  int64
#  7   TWF                      10000 non-null  int64
#  8   HDF                      10000 non-null  int64
#  9   PWF                      10000 non-null  int64
#  10  OSF                      10000 non-null  int64
#  11  RNF                      10000 non-null  int64
# dtypes: float64(5), int64(7)
# memory usage: 937.6 KB

# %%
print("Missing Values Per Column:")
print(df.isnull().sum())
print("Total Missing Values:")
print(df.isnull().sum().sum())
# Out:
# Missing Values Per Column:
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Machine failure            0
# TWF                        0
# HDF                        0
# PWF                        0
# OSF                        0
# RNF                        0
# dtype: int64
# Total Missing Values:
# 0

# %%
duplicates = df.duplicated().sum()

print("Duplicate Records Found:")
print(duplicates)
# Out:
# Duplicate Records Found:
# 0

# %%
df.describe()
# Out:
#               Type  Air temperature [K]  Process temperature [K]  \
# count  10000.00000         1.000000e+04             1.000000e+04
# mean       1.19940        -1.000444e-15            -1.693934e-15
# std        0.60023         1.000050e+00             1.000050e+00
# min        0.00000        -2.352278e+00            -2.901986e+00
# 25%        1.00000        -8.523974e-01            -8.125581e-01
# 50%        1.00000         4.753123e-02             6.365340e-02
# 75%        2.00000         7.474757e-01             7.376623e-01
# max        2.00000         2.247357e+00             2.557486e+00
#
#        Rotational speed [rpm]   Torque [Nm]  Tool wear [min]  Machine failure  \
# count            1.000000e+04  1.000000e+04     1.000000e+04     10000.000000
# mean            -2.302158e-16  5.485390e-16     9.663381e-17         0.033900
# std              1.000050e+00  1.000050e+00     1.000050e+00         0.180981
# ...

# %%
print(df["Machine failure"].value_counts())
print(df["Machine failure"].value_counts(normalize=True)*100)
# Out:
# Machine failure
# 0    9661
# 1     339
# Name: count, dtype: int64
# Machine failure
# 0    96.61
# 1     3.39
# Name: proportion, dtype: float64

# %%
failure_cols = ["TWF","HDF","PWF","OSF","RNF"]

for col in failure_cols:
    print(f"\n{col}")
    print(df[col].value_counts())
# Out:
# TWF
# TWF
# 0    9954
# 1      46
# Name: count, dtype: int64
#
# HDF
# HDF
# 0    9885
# 1     115
# Name: count, dtype: int64
#
# PWF
# PWF
# 0    9905
# 1      95
# Name: count, dtype: int64
#
# OSF
# OSF
# 0    9902
# 1      98
# Name: count, dtype: int64
#
# RNF
# RNF
# 0    9981
# 1      19
# Name: count, dtype: int64

# %%
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Type: 3 unique values
# Air temperature [K]: 93 unique values
# Process temperature [K]: 82 unique values
# Rotational speed [rpm]: 941 unique values
# Torque [Nm]: 577 unique values
# Tool wear [min]: 246 unique values
# Machine failure: 2 unique values
# TWF: 2 unique values
# HDF: 2 unique values
# PWF: 2 unique values
# OSF: 2 unique values
# RNF: 2 unique values

# %%
print("Dataset Shape:", df.shape)
print("Missing Values:", df.isnull().sum().sum())
print("Duplicate Records:", df.duplicated().sum())
# Out:
# Dataset Shape: (10000, 12)
# Missing Values: 0
# Duplicate Records: 0

# %%
print(""" DATASET VALIDATION SUMMARY 
Rows: 10000 Columns: 12 Missing Values: 0 Duplicate Records: 0 Data Types Valid: Yes Dataset Integrity: Passed Status: Dataset is ready for feature engineering and machine learning modeling. """)
