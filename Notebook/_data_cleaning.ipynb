# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/ankit/Predictive-Maintenance-IoT-AI/Data/ai4i2020.csv")
print(df.columns)
# Out:
# Index(['UDI', 'Product ID', 'Type', 'Air temperature [K]',
#        'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]',
#        'Tool wear [min]', 'Machine failure', 'TWF', 'HDF', 'PWF', 'OSF',
#        'RNF'],
#       dtype='object')

# %%
print(df.shape)
print(df.info())
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# (10000, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UDI                      10000 non-null  int64
#  1   Product ID               10000 non-null  object
#  2   Type                     10000 non-null  object
#  3   Air temperature [K]      10000 non-null  float64
#  4   Process temperature [K]  10000 non-null  float64
#  5   Rotational speed [rpm]   10000 non-null  int64
#  6   Torque [Nm]              10000 non-null  float64
#  7   Tool wear [min]          10000 non-null  int64
#  8   Machine failure          10000 non-null  int64
#  9   TWF                      10000 non-null  int64
#  10  HDF                      10000 non-null  int64
#  11  PWF                      10000 non-null  int64
#  12  OSF                      10000 non-null  int64
#  13  RNF                      10000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# UDI                        0
# Product ID                 0
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Machine failure            0
# TWF                        0
# HDF                        0
# PWF                        0
# OSF                        0
# RNF                        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop(['UDI', 'Product ID'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Type'] = le.fit_transform(df['Type'])

# %%
print(df.shape)
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# (10000, 12)
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Machine failure            0
# TWF                        0
# HDF                        0
# PWF                        0
# OSF                        0
# RNF                        0
# dtype: int64
# 0

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Type'] = le.fit_transform(df['Type'])

print(df['Type'].unique())
# Out:
# [2 1 0]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

cols = [
    'Air temperature [K]',
    'Process temperature [K]',
    'Rotational speed [rpm]',
    'Torque [Nm]',
    'Tool wear [min]'
]

df[cols] = scaler.fit_transform(df[cols])

df.head()
# Out:
#    Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0     2            -0.952389                -0.947360                0.068185
# 1     1            -0.902393                -0.879959               -0.729472
# 2     1            -0.952389                -1.014761               -0.227450
# 3     1            -0.902393                -0.947360               -0.590021
# 4     1            -0.902393                -0.879959               -0.729472
#
#    Torque [Nm]  Tool wear [min]  Machine failure  TWF  HDF  PWF  OSF  RNF
# 0     0.282200        -1.695984                0    0    0    0    0    0
# 1     0.633308        -1.648852                0    0    0    0    0    0
# 2     0.944290        -1.617430                0    0    0    0    0    0
# 3    -0.048845        -1.586009                0    0    0    0    0    0
# 4     0.001313        -1.554588                0    0    0    0    0    0

# %%
df.to_csv("C:/Users/ankit/Predictive-Maintenance-IoT-AI/Data/ai4i2020.csv", index=False)

# %%
df.to_csv(
    "C:/Users/ankit/Predictive-Maintenance-IoT-AI/Data/preprocessed_ai4i2020.csv",
    index=False
)

print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %%
import pandas as pd

df2 = pd.read_csv(
    "C:/Users/ankit/Predictive-Maintenance-IoT-AI/Data/preprocessed_ai4i2020.csv"
)

print(df2.shape)
df2.head()
# Out:
# (10000, 12)
#    Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0     2            -0.952389                -0.947360                0.068185
# 1     1            -0.902393                -0.879959               -0.729472
# 2     1            -0.952389                -1.014761               -0.227450
# 3     1            -0.902393                -0.947360               -0.590021
# 4     1            -0.902393                -0.879959               -0.729472
#
#    Torque [Nm]  Tool wear [min]  Machine failure  TWF  HDF  PWF  OSF  RNF
# 0     0.282200        -1.695984                0    0    0    0    0    0
# 1     0.633308        -1.648852                0    0    0    0    0    0
# 2     0.944290        -1.617430                0    0    0    0    0    0
# 3    -0.048845        -1.586009                0    0    0    0    0    0
# 4     0.001313        -1.554588                0    0    0    0    0    0
