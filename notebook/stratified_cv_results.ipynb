# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("../data/contextual_merged_dataset.csv")

target = "Machine failure"

X = df.drop(columns=[target])
y = df[target]

# Handle categorical variables
X = pd.get_dummies(X, drop_first=True)

print("Dataset Shape:", X.shape)
print("\nClass Distribution:")
print(y.value_counts())
# Out:
# Dataset Shape: (10000, 30016)
#
# Class Distribution:
# Machine failure
# 0    9661
# 1     339
# Name: count, dtype: int64

# %%
skf = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %%
model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

fold_results = []

for fold, (train_idx, test_idx) in enumerate(skf.split(X, y), start=1):

    X_train = X.iloc[train_idx]
    X_test = X.iloc[test_idx]

    y_train = y.iloc[train_idx]
    y_test = y.iloc[test_idx]

    model.fit(X_train, y_train)

    predictions = model.predict(X_test)

    accuracy = accuracy_score(y_test, predictions)

    fold_results.append(accuracy)

    print(f"Fold {fold} Accuracy: {accuracy:.4f}")
# Out:
# Fold 1 Accuracy: 0.9955
# Fold 2 Accuracy: 0.9885
# Fold 3 Accuracy: 0.9910
# Fold 4 Accuracy: 0.9960
# Fold 5 Accuracy: 0.9955

# %%
results_df = pd.DataFrame({
    "Fold": [1, 2, 3, 4, 5],
    "Accuracy": fold_results
})

results_df
# Out:
#    Fold  Accuracy
# 0     1    0.9955
# 1     2    0.9885
# 2     3    0.9910
# 3     4    0.9960
# 4     5    0.9955

# %%
mean_accuracy = np.mean(fold_results)
std_accuracy = np.std(fold_results)

print(f"\nMean Accuracy: {mean_accuracy:.4f}")
print(f"Standard Deviation: {std_accuracy:.4f}")
# Out:
# Mean Accuracy: 0.9933
# Standard Deviation: 0.0030

# %%
print("\nStratified 5-Fold Cross Validation Completed Successfully")
# Out:
# Stratified 5-Fold Cross Validation Completed Successfully
