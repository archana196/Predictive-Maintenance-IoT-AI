# %%
import pandas as pd
import  numpy as np 
import lightgbm as lgb

# %%
df= pd.read_csv("../data/week1_features.csv")
df.head()
df.columns = df.columns.str.replace('[', '_', regex=False)
df.columns = df.columns.str.replace(']', '_', regex=False)
df.columns = df.columns.str.replace(' ', '_', regex=False)

# %%
df.shape
# Out:
# (10000, 64)

# %%
y=df["Machine failure"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\INDIA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Machine failure'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df["Machine failure"]
#
# File c:\Users\INDIA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\INDIA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Machine failure'

# %%
feature_cols = [col for col in df.columns if 'roll' in col]
X = df[feature_cols]
y = df["Machine failure"]
print("Features:", X.shape[1])
print("Target distribution:", y.value_counts().to_dict())
# Out:
# Features: 50
# Target distribution: {0: 9661, 1: 339}

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape
# Out:
# (8000, 50)

# %%
X_test.shape
# Out:
# (2000, 50)

# %%
feature_cols = [col for col in df.columns if 'roll' in col]
X = df[feature_cols]
y = df["Machine failure"]
X.columns = X.columns.str.replace('[', '_', regex=False)
X.columns = X.columns.str.replace(']', '_', regex=False)
X.columns = X.columns.str.replace(' ', '_', regex=False)

print("Features:", X.shape[1])
# Out:
# Features: 50

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
print("Macro F1:", f1_score(y_test, y_pred, average='macro'))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 y_pred = model.predict(X_test)
#       2 print(classification_report(y_test, y_pred))
#       3 print("Macro F1:", f1_score(y_test, y_pred, average='macro'))
#
# File c:\Users\INDIA\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightgbm\sklearn.py:1597, in LGBMClassifier.predict(self, X, raw_score, start_iteration, num_iteration, pred_leaf, pred_contrib, validate_features, **kwargs)
#    1585 def predict(
#    1586     self,
#    1587     X: _LGBM_ScikitMatrixLike,
#    (...)   1594     **kwargs: Any,
#    1595 ):
#    1596     """Docstring is inherited from the LGBMModel."""
# -> 1597     result = self.predict_proba(
#    1598         X=X,
#    1599         raw_score=raw_score,
#    1600         start_iteration=start_iteration,
#    1601         num_iteration=num_iteration,
#    1602         pred_leaf=pred_leaf,
#    1603         pred_contrib=pred_contrib,
#    1604         validate_features=validate_features,
#    1605         **kwargs,
#    1606     )
#    1607     if callable(self._objective) or raw_score or pred_leaf or pred_contrib:
#    1608         return result
#
# File c:\Users\INDIA\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightgbm\sklearn.py:1627, in LGBMClassifier.predict_proba(self, X, raw_score, start_iteration, num_iteration, pred_leaf, pred_contrib, validate_features, **kwargs)
#    1615 def predict_proba(
#    1616     self,
#    1617     X: _LGBM_ScikitMatrixLike,
#    (...)   1624     **kwargs: Any,
#    1625 ):
#    1626     """Docstring is set after definition, using a template."""
# -> 1627     result = super().predict(
#    1628         X=X,
#    1629         raw_score=raw_score,
#    1630         start_iteration=start_iteration,
#    1631         num_iteration=num_iteration,
#    1632         pred_leaf=pred_leaf,
#    1633         pred_contrib=pred_contrib,
#    1634         validate_features=validate_features,
#    1635         **kwargs,
#    1636     )
#    1637     if callable(self._objective) and not (raw_score or pred_leaf or pred_contrib):
#    1638         _log_warning(
#    1639             "Cannot compute class probabilities or labels "
#    1640             "due to the usage of customized objective function.\n"
#    1641             "Returning raw scores instead."
#    1642         )
#
# File c:\Users\INDIA\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightgbm\sklearn.py:1106, in LGBMModel.predict(self, X, raw_score, start_iteration, num_iteration, pred_leaf, pred_contrib, validate_features, **kwargs)
#    1104 """Docstring is set after definition, using a template."""
#    1105 if not self.__sklearn_is_fitted__():
# -> 1106     raise LGBMNotFittedError("Estimator not fitted, call fit before exploiting the model.")
#    1107 if not isinstance(X, (pd_DataFrame, dt_DataTable)):
#    1108     X = _LGBMValidateData(
#    1109         self,
#    1110         X,
#    (...)   1121         ensure_min_samples=1,
#    1122     )
#
# NotFittedError: Estimator not fitted, call fit before exploiting the model.
