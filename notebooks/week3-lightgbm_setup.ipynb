# %%
import pandas as pd
import  numpy as np 
import lightgbm as lgb

# %%
df= pd.read_csv("../data/week1_features.csv")
df.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Machine failure  TWF  \
# 0                    1551         42.8                0                0    0
# 1                    1408         46.3                3                0    0
# 2                    1498         49.4                5                0    0
# 3                    1433         39.5                7                0    0
# 4                    1408         40.0                9                0    0
#
#    ...  Rotational speed [rpm]_rollmin_10  Rotational speed [rpm]_rollmax_10  \
# 0  ...                             1551.0                             1551.0
# 1  ...                             1408.0                             1551.0
# 2  ...                             1408.0                             1551.0
# 3  ...                             1408.0                             1551.0
# 4  ...                             1408.0                             1551.0
#
#    Torque [Nm]_rollmin_5  Torque [Nm]_rollmax_5  Torque [Nm]_rollmin_10  \
# 0                   42.8                   42.8                    42.8
# 1                   42.8                   46.3                    42.8
# 2                   42.8                   49.4                    42.8
# 3                   39.5                   49.4                    39.5
# 4                   39.5                   49.4                    39.5
#
#    Torque [Nm]_rollmax_10  Tool wear [min]_rollmin_5  \
# 0                    42.8                        0.0
# 1                    46.3                        0.0
# 2                    49.4                        0.0
# 3                    49.4                        0.0
# 4                    49.4                        0.0
#
#    Tool wear [min]_rollmax_5  Tool wear [min]_rollmin_10  \
# 0                        0.0                         0.0
# 1                        3.0                         0.0
# 2                        5.0                         0.0
# 3                        7.0                         0.0
# 4                        9.0                         0.0
#
#    Tool wear [min]_rollmax_10
# 0                         0.0
# 1                         3.0
# 2                         5.0
# 3                         7.0
# 4                         9.0
#
# [5 rows x 64 columns]

# %%
df.shape
# Out:
# (10000, 64)

# %%
df["Machine failure"].value_counts()
# Out:
# Machine failure
# 0    9661
# 1     339
# Name: count, dtype: int64

# %%
feature_cols = [col for col in df.columns if 'roll' in col]
X = df[feature_cols]
y = df["Machine failure"]
print("Features:", X.shape[1])
print("Target distribution:", y.value_counts().to_dict())
# Out:
# Features: 50
# Target distribution: {0: 9661, 1: 339}

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape
# Out:
# (8000, 50)

# %%
X_test.shape
# Out:
# (2000, 50)

# %%
feature_cols = [col for col in df.columns if 'roll' in col]
X = df[feature_cols]
y = df["Machine failure"]
X.columns = X.columns.str.replace('[', '_', regex=False)
X.columns = X.columns.str.replace(']', '_', regex=False)
X.columns = X.columns.str.replace(' ', '_', regex=False)

print("Features:", X.shape[1])
# Out:
# Features: 50
